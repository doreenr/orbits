# %%
import scipy
from scipy import spatial
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
from scipy.spatial import ConvexHull
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

#path = ('/Users/Doreen/github/orbits/UniversalMaven/outputall100000.csv')
path = ('/Users/Doreen/github/orbits/Matlab/P6_10000.csv')
#path = ('/Users/Doreen/github/orbits/UniversalMaven/outputall6000.csv')
# path = ('/Users/Doreen/github/orbits/UniversalMaven/outputall4000.csv')
#path = ('/Users/Doreen/github/orbits/UniversalMaven/outputall2000.csv')
pts = genfromtxt(path, delimiter=',', skip_footer=1)
print pts.shape

m1 = PCA(n_components=4).fit(pts)
proj1 = m1.transform(pts)
np.savetxt('/Users/Doreen/github/orbits/Matlab/transP6_10000.txt', proj1, delimiter=" ") 

# np.savetxt('/Users/Doreen/github/orbits/Matlab/P1_10000.txt', pts, delimiter=" ") 

hull1 = ConvexHull(proj1, qhull_options = "Qx E0.01")
print len(hull1.vertices)
print hull1.vertices
# Out:
# (9999, 6)
# 187
# [  79  160  161  241  242  243  404  405  704  708  709  787  788  899  900
#   949  950  951  985  986 1112 1385 1386 1467 1468 1469 1495 1496 1631 1657
#  1658 1659 1819 1820 1930 1931 1932 1982 2013 2093 2094 2144 2172 2305 2306
#  2367 2476 2477 2480 2481 2528 2529 2638 2639 2640 2912 3267 3268 3319 3320
#  3702 3783 3864 3865 3866 3944 3945 3975 3976 4027 4028 4165 4166 4327 4328
#  4329 4410 4411 4572 4573 4574 4683 4684 4845 4846 4847 4957 4958 5008 5009
#  5090 5091 5092 5118 5119 5120 5253 5254 5280 5281 5282 5391 5392 5439 5442
#  5443 5553 5554 5555 5636 5715 5716 5717 5826 5827 5828 5878 5988 5989 5990
#  6098 6099 6100 6151 6201 6202 6261 6262 6263 6363 6364 6424 6425 6479 6890
#  6942 6943 7325 7406 7487 7488 7489 7567 7568 7598 7599 7950 7951 7952 8033
#  8275 8276 8306 8307 8468 8469 8470 8497 8631 8632 9014 9015 9016 9176 9177
#  9178 9259 9338 9339 9340 9370 9371 9449 9501 9613 9639 9640 9641 9648 9721
#  9722 9723 9770 9771 9884 9885 9886]

# %%
path = ('/Users/Doreen/github/orbits/UniversalMaven/outputallP2100000.csv')
pts = genfromtxt(path, delimiter=',')
print pts.shape
m1 = PCA(n_components=4).fit(pts)
proj1 = m1.transform(pts)
hull1 = ConvexHull(proj1, qhull_options = "Q9, E0.001")
print len(hull1.vertices)
print hull1.vertices
# Out:
# (100000, 6)
# 53
# [  230  3022  3168  3316  8142 10118 11004 11005 13686 14566 16109 18168
#  21109 24012 24159 24161 27651 29160 29161 30669 30961 30962 31107 31254
#  31255 34194 37212 38057 38204 50297 78935 79228 79229 79375 83013 84815
#  85771 85772 86177 86178 86471 87280 87281 87496 87497 88928 90177 92314
#  93272 93273 93565 93566 94228]

# %%
path = ('/Users/Doreen/github/orbits/UniversalMaven/outputallP3100000.csv')
pts = genfromtxt(path, delimiter=',')
print pts.shape
m1 = PCA(n_components=4).fit(pts)
proj1 = m1.transform(pts)
np.savetxt('transformedPCA_10000P3.txt', proj1, delimiter=" ") 
hull1 = ConvexHull(proj1, qhull_options = "Q9, E0.01")
print len(hull1.vertices)
print proj1
# Out:
# (100000, 6)
# 9
# [[ -1.90956658e+00   1.60470846e+00  -5.92722061e-01  -2.84201792e-01]
#  [  3.51094129e+00   2.22478192e-01   1.82242963e-02   2.56606571e-01]
#  [ -2.64332132e+00  -2.23190558e+00   4.79307826e-02  -7.17642447e-02]
#  ...,
#  [ -8.53855257e-01   6.04045394e-04  -1.49534182e-01   6.82400195e-01]
#  [ -1.19861560e+00   2.17726944e+00  -6.37016417e-01  -3.43294119e-01]
#  [  4.00962928e+00  -1.50130704e-01   2.82066379e-01  -7.20123186e-02]]

# %%
from matplotlib import pyplot as plt
from pylab import *
from mpl_toolkits.mplot3d.axes3d import Axes3D
step = 0.1
mini = np.min(proj1[:,3])
maxi = np.max(proj1[:,3])

fig = plt.figure()
ax1 = fig.add_subplot(231, projection='3d')
ax2 = fig.add_subplot(232, projection='3d')
ax3 = fig.add_subplot(233, projection='3d')
ax4 = fig.add_subplot(234, projection='3d')
ax5 = fig.add_subplot(235, projection='3d')
ax6 = fig.add_subplot(236, projection='3d')
for index in range(0, (len(proj1[:,0])/10)):
    if (proj1[:,3][index]) > mini and (proj1[:,3][index]) <= (mini+step):
        sc1 = ax1.scatter(proj1[index, 0], proj1[index, 1], proj1[index, 2], color = "Blue", s=0.1, alpha=0.3) 
    elif (proj1[:,3][index]) > (mini+step) and (proj1[:,3][index]) <= (mini+(2*step)):
        sc2 = ax2.scatter(proj1[index, 0], proj1[index, 1], proj1[index, 2], color = "Blue", s=0.1, alpha=0.3)
    elif (proj1[:,3][index]) > (mini+(2*step)) and (proj1[:,3][index]) <= (mini+(3*step)):
        sc3 = ax3.scatter(proj1[index, 0], proj1[index, 1], proj1[index, 2], color = "Blue", s=0.1, alpha=0.3)
    elif (proj1[:,3][index]) > (mini+(3*step)) and (proj1[:,3][index]) <= (mini+(4*step)):
        sc4 = ax4.scatter(proj1[index, 0], proj1[index, 1], proj1[index, 2], color = "Blue", s=0.1, alpha=0.3)
    elif (proj1[:,3][index]) > (mini+(4*step)) and (proj1[:,3][index]) <= (mini+(5*step)):
        sc5 = ax5.scatter(proj1[index, 0], proj1[index, 1], proj1[index, 2], color = "Blue", s=0.1, alpha=0.3)
    elif (proj1[:,3][index]) > (mini+(5*step)) and (proj1[:,3][index]) <= (mini+(6*step)):
        sc6 = ax6.scatter(proj1[index, 0], proj1[index, 1], proj1[index, 2], color = "Blue", s=0.1, alpha=0.3)

for a in hull1.vertices:
    x = proj1[a][0]
    y = proj1[a][1]
    z = proj1[a][2]
    ax1.scatter(x, y, z, color = "Red", alpha=0.6)          
    ax2.scatter(x, y, z, color = "Red", alpha=0.6)          
    ax3.scatter(x, y, z, color = "Red", alpha=0.6)          
    ax4.scatter(x, y, z, color = "Red", alpha=0.6)          
    ax5.scatter(x, y, z, color = "Red", alpha=0.6)          
    ax6.scatter(x, y, z, color = "Red", alpha=0.6)          
#sc1 = ax1.scatter(proj1[:, index], proj1[:, index], proj1[:, index], color = "Blue", s=0.1, alpha=0.3)
#sc2 = ax2.scatter(proj1[:, 0], proj1[:, 1], proj1[:, 2], color = "Blue", s=0.1, alpha=0.3)
#sc3 = ax3.scatter(proj1[:, 0], proj1[:, 1], proj1[:, 2], color = "Blue", s=0.1, alpha=0.3)
#sc4 = ax4.scatter(proj1[:, 0], proj1[:, 1], proj1[:, 2], color = "Blue", s=0.1, alpha=0.3)
#sc5 = ax5.scatter(proj1[:, 0], proj1[:, 1], proj1[:, 2], color = "Blue", s=0.1, alpha=0.3)
#sc6 = ax6.scatter(proj1[:, 0], proj1[:, 1], proj1[:, 2], color = "Blue", s=0.1, alpha=0.3)
plt.show()

# %%
plt.show()

# %%
# slice 4th column into 7 parts

print proj1.shape
print np.min(proj1[:,3])
print np.mean(proj1[:,3])
print np.max(proj1[:,3])
step = 0.1
mini = np.min(proj1[:,3])
maxi = np.max(proj1[:,3])
a2 = proj1
a3 = proj1

proj3D = np.delete(proj1,(3), axis=1)
print proj3D.shape

indi1 = []
indi2 = []
indi3 = []
indi4 = []
indi5 = []
indi6 = []
indi7 = []

for index in range(0, len(proj1[:,0])):
    if (proj1[:,3][index]) > mini and (proj1[:,3][index]) <= (mini+step):
        indi1.append(index)  
    elif (proj1[:,3][index]) > (mini+step) and (proj1[:,3][index]) <= (mini+(2*step)):
        indi2.append(index)   
    elif (proj1[:,3][index]) > (mini+(2*step)) and (proj1[:,3][index]) <= (mini+(3*step)):
        indi3.append(index)    
    elif (proj1[:,3][index]) > (mini+(3*step)) and (proj1[:,3][index]) <= (mini+(4*step)):
        indi4.append(index)    
    elif (proj1[:,3][index]) > (mini+(4*step)) and (proj1[:,3][index]) <= (mini+(5*step)):
        indi5.append(index)    
    elif (proj1[:,3][index]) > (mini+(5*step)) and (proj1[:,3][index]) <= (mini+(6*step)):
        indi6.append(index)
    elif (proj1[:,3][index]) > (mini+(6*step)) and (proj1[:,3][index]) <= (mini+(7*step)):
        indi7.append(index)
        # print index
        
print len(indi1), len(indi2), len(indi3), len(indi4), len(indi5), len(indi6), len(indi7)
#print a1.shape, a2.shape, a3.shape
# slice matrix
#array = np.empty(len(indi1))
#print array.shape
# Out:
# (2000, 4)
# -0.287312499094
# -1.77260983669e-16
# 0.303333569098
# (2000, 3)
# 322 337 487 263 277 313 0

# %%
# Plot initial points (0-1-2 axis projection) and obtained vertices
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for a in range(0, (len(pts)/1000)):
    x = pts[a][0]
    y = pts[a][1]
    z = pts[a][2]
    ax.scatter(x, y, z, color = "Blue", s=0.1, alpha=0.3)
for a in hull1.vertices:
    x = pts[a][0]
    y = pts[a][1]
    z = pts[a][2]
    ax.scatter(x, y, z, color = "Red", alpha=0.9)
plt.show()

# %%
# Plot the projected points (on 4-D hyperplane) in a 0-1-2 projection
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for a in range(0, ((len(proj1))/6)):
    x = proj1[a][0]
    y = proj1[a][1]
    z = proj1[a][2]
    ax.scatter(x, y, z, color = "Blue", s=0.1, alpha=0.3)
for a in hull1.vertices:
    x = proj1[a][0]
    y = proj1[a][1]
    z = proj1[a][2]
    ax.scatter(x, y, z, color = "Red", alpha=0.6)    
plt.show()

# %%
from matplotlib import pyplot as plt
import time
plt.ion()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# sc = ax.scatter(proj1[:, 0], proj1[:, 1], proj1[:, 2])
for a in indi1:
    ix = proj1[a][0]
    iy = proj1[a][1]
    iz = proj1[a][2]
    sc = ax.scatter(ix, iy, iz, color = "Blue", s=0.1, alpha=0.3)
for a in hull1.vertices:
    x = proj1[a][0]
    y = proj1[a][1]
    z = proj1[a][2]
    ax.scatter(x, y, z, color = "Red", alpha=0.9)
fig.show()

for i in range(0, 10):
    plt.pause(1)
    if i == 1:
        for a in indi1:
            ix = proj1[a][0]
            iy = proj1[a][1]
            iz = proj1[a][2]
            sc._offsets3d = (ix, iy, iz)
    plt.draw()
    
###


for a in indi2:
    ix = proj1[a][0]
    iy = proj1[a][1]
    iz = proj1[a][2]
    # ax.scatter(ix, iy, iz, color = "Cyan", s=0.1, alpha=0.3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

def Gen_RandLine(length, dims=2) :
    lineData = np.empty((dims, length))
    lineData[:, 0] = np.random.rand(dims)
    for index in range(1, length) :
        step = ((np.random.rand(dims) - 0.5) * 0.1)
        lineData[:, index] = lineData[:, index-1] + step
    return lineData

def update_lines(num, dataLines, lines) :
    for line, data in zip(lines, dataLines) :
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2,:num])
    return lines

# Attaching 3D axis to the figure
fig = plt.figure()
ax = p3.Axes3D(fig)

# Fifty lines of random 3-D lines
data = [Gen_RandLine(25, 3) for index in range(10)]

# Creating fifty line objects.
# NOTE: Can't pass empty arrays into 3d version of plot()
lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]

# Creating the Animation object
line_ani = animation.FuncAnimation(fig, update_lines, 70, fargs=(data, lines), interval=100, blit=False)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib.animation import FuncAnimation

# slice 4th column into 20 parts
print proj1.shape
print np.min(proj1[:,3])
print np.mean(proj1[:,3])
print np.max(proj1[:,3])

step = 0.1
mini = np.min(proj1[:,3])
maxi = np.max(proj1[:,3])
indi1 = []
indi2 = []
indi3 = []
indi4 = []
indi5 = []
indi6 = []
indi7 = []

for index in range(0, len(proj1[:,0])):
    if (proj1[:,3][index]) > mini and (proj1[:,3][index]) <= (mini+step):
        indi1.append(index)
    elif (proj1[:,3][index]) > (mini+step) and (proj1[:,3][index]) <= (mini+(2*step)):
        indi2.append(index)    
    elif (proj1[:,3][index]) > (mini+(2*step)) and (proj1[:,3][index]) <= (mini+(3*step)):
        indi3.append(index)    
    elif (proj1[:,3][index]) > (mini+(3*step)) and (proj1[:,3][index]) <= (mini+(4*step)):
        indi4.append(index)    
    elif (proj1[:,3][index]) > (mini+(4*step)) and (proj1[:,3][index]) <= (mini+(5*step)):
        indi5.append(index)    
    elif (proj1[:,3][index]) > (mini+(5*step)) and (proj1[:,3][index]) <= (mini+(6*step)):
        indi6.append(index)
    elif (proj1[:,3][index]) > (mini+(6*step)) and (proj1[:,3][index]) <= (mini+(7*step)):
        indi7.append(index)
        # print index

print len(indi1)
print len(indi2)
print len(indi3)
print len(indi4)
print len(indi5)
print len(indi6)
print len(indi7)

def update_plot(num, data, sc):
    print sc._offsets3d
    sc._offsets3d = data[num]
    return sc

# numframes = 10
# data = np.random.rand(numframes, 3, 1)# a (time, position) array

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for a in indi1:
    ix = proj1[a][0]
    iy = proj1[a][1]
    iz = proj1[a][2]
    ax.scatter(ix, iy, iz, color = "Blue", s=0.1, alpha=0.3)
for a in indi2:
    ix = proj1[a][0]
    iy = proj1[a][1]
    iz = proj1[a][2]
    ax.scatter(ix, iy, iz, color = "Cyan", s=0.1, alpha=0.3)
    
for a in hull1.vertices:
    x = proj1[a][0]
    y = proj1[a][1]
    z = proj1[a][2]
    ax.scatter(x, y, z, color = "Red", alpha=0.9)
    
    
# ix, iy, iz = data[0]
# sc = ax.scatter(ix, iy, iz, c='k')
# ani = FuncAnimation(fig, update_plot, frames=numframes, fargs=(data,sc))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-69b76a273d2c> in <module>()
#       5
#       6 # slice 4th column into 20 parts
# ----> 7 print proj1.shape
#       8 print np.min(proj1[:,3])
#       9 print np.mean(proj1[:,3])
#
# NameError: name 'proj1' is not defined

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(ix, iy, iz, color = "Blue", s=0.1, alpha=0.3)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=False)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
# anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

plt.show()

# %%
def in_hull(p, hull):
    """
    Test if points in `p` are in `hull`

    `p` should be a `NxK` coordinates of `N` points in `K` dimensions
    `hull` is either a scipy.spatial.Delaunay object or the `MxK` array of the 
    coordinates of `M` points in `K`dimensions for which Delaunay triangulation
    will be computed
    """
    from scipy.spatial import Delaunay
    if not isinstance(hull,Delaunay):
        hull = Delaunay(hull)
    return hull.find_simplex(p)>=0

def plot_in_hull(p, hull):
    """
    plot relative to `in_hull` for 2d data
    """
    import matplotlib.pyplot as plt
    from matplotlib.collections import PolyCollection, LineCollection

    from scipy.spatial import Delaunay
    if not isinstance(hull,Delaunay):
        hull = Delaunay(hull)

    # plot triangulation
    poly = PolyCollection(hull.points[hull.vertices], facecolors='w', edgecolors='b')
    plt.clf()
    plt.title('in hull')
    plt.gca().add_collection(poly)
    plt.plot(hull.points[:,0], hull.points[:,1], 'o', hold=1)

    # plot the convex hull
    edges = set()
    edge_points = []

    def add_edge(i, j):
        """Add a line between the i-th and j-th points, if not in the list already"""
        if (i, j) in edges or (j, i) in edges:
            # already added
            return
        edges.add( (i, j) )
        edge_points.append(hull.points[ [i, j] ])

    for ia, ib in hull.convex_hull:
        add_edge(ia, ib)

    lines = LineCollection(edge_points, color='g')
    plt.gca().add_collection(lines)
    plt.show()    

    # plot tested points `p` - black are inside hull, red outside
    inside = in_hull(p,hull)
    plt.plot(p[ inside,0],p[ inside,1],'.k')
    plt.plot(p[-inside,0],p[-inside,1],'.r')
    
new  = proj1[:, [0, 1]]
rando  = pts[:, [0, 1]]
print new.shape

print in_hull(proj1, proj1)
# plot_in_hull(rando, new)
# Out:
# (2000, 2)
# [ True  True  True ...,  True False  True]

# %%
# Out:
# (2000, 6)
